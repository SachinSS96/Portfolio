# %% [markdown]
# ## ${\textbf{Libraries}}$

# %%
# I need to save the models, which I'll use in the next section. I'll use pickle for that.
import pickle

# Sk learn is one of the most widely used libraries for machine learning. I'll use the k means and pca modules.


from sklearn.decomposition import PCA


from sklearn.cluster import KMeans

# Hierarchical clustering with the Sci Py library. I'll use the dendrogram and linkage modules.
from scipy.cluster.hierarchy import dendrogram, linkage

# For standardizing features. I'll use the StandardScaler module.
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="ticks")
plt.style.use("dark_background")

# %% [markdown]
# ## ${\textbf{Import Data}}$

# %%
# Load the data, contained in the segmentation data csv file.
df_segmentation = pd.read_csv("data/segmentation data.csv", index_col=0)

# %% [markdown]
# ## ${\textbf{Explore Data}}$

# %%
df_segmentation.head()
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
#
#            Settlement size
# ID
# 100000001                2
# 100000002                2
# 100000003                0
# 100000004                1
# 100000005                1

# %%
df_segmentation.describe()
# Out:
#                Sex  Marital status          Age   Education         Income  \
# count  2000.000000     2000.000000  2000.000000  2000.00000    2000.000000
# mean      0.457000        0.496500    35.909000     1.03800  120954.419000
# std       0.498272        0.500113    11.719402     0.59978   38108.824679
# min       0.000000        0.000000    18.000000     0.00000   35832.000000
# 25%       0.000000        0.000000    27.000000     1.00000   97663.250000
# 50%       0.000000        0.000000    33.000000     1.00000  115548.500000
# 75%       1.000000        1.000000    42.000000     1.00000  138072.250000
# max       1.000000        1.000000    76.000000     3.00000  309364.000000
#
#         Occupation  Settlement size
# count  2000.000000      2000.000000
# mean      0.810500         0.739000
# std       0.638587         0.812533
# min       0.000000         0.000000
# 25%       0.000000         0.000000
# 50%       1.000000         1.000000
# ...

# %% [markdown]
# ## ${\textbf{Correlation Estimate}}$

# %%
df_segmentation.corr()
# Out:
#                       Sex  Marital status       Age  Education    Income  \
# Sex              1.000000        0.566511 -0.182885   0.244838 -0.195146
# Marital status   0.566511        1.000000 -0.213178   0.374017 -0.073528
# Age             -0.182885       -0.213178  1.000000   0.654605  0.340610
# Education        0.244838        0.374017  0.654605   1.000000  0.233459
# Income          -0.195146       -0.073528  0.340610   0.233459  1.000000
# Occupation      -0.202491       -0.029490  0.108388   0.064524  0.680357
# Settlement size -0.300803       -0.097041  0.119751   0.034732  0.490881
#
#                  Occupation  Settlement size
# Sex               -0.202491        -0.300803
# Marital status    -0.029490        -0.097041
# Age                0.108388         0.119751
# Education          0.064524         0.034732
# Income             0.680357         0.490881
# Occupation         1.000000         0.571795
# Settlement size    0.571795         1.000000

# %%
# I'll plot the correlations using a Heat Map. Heat Maps are a great way to visualize correlations using color coding.
# I use crest as a color scheme, but you can use viridis, Blues, YlGnBu or many others.
# I set the range from -1 to 1, as it is the range of the Pearson Correlation.
# Otherwise the function infers the boundaries from the input.
# In this case they will be -0,25 to 0,68, as they are the minumum and maximum correlation indeces between our features.
plt.figure(figsize=(10, 6))
s = sns.heatmap(df_segmentation.corr(), annot=True, cmap="crest", vmin=-1, vmax=1)
s.set_yticklabels(s.get_yticklabels(), rotation=0, fontsize=10)
s.set_xticklabels(s.get_xticklabels(), rotation=45, fontsize=10)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## ${\textbf{Visualize Raw Data}}$

# %%
# I'll plot the data. I create a 12 by 9 inches figure.
# I have 2000 data points, which I'll scatter acrros Age and Income, located on positions 2 and 4 in our data set.
plt.figure(figsize=(8, 8))
plt.scatter(df_segmentation.iloc[:, 2], df_segmentation.iloc[:, 4])
plt.xlabel("Age")
plt.ylabel("Income")
plt.title("Visualization of raw data")
# Out:
# Text(0.5, 1.0, 'Visualization of raw data')

# %% [markdown]
# ## ${\textbf{Standardization}}$

# %%
# Standardizing data, so that all features have equal weight. This is important for modelling.
# Otherwise, in our case Income would be considered much more important than Education for Instance.
# I do not know if this is the case, so I would not like to introduce it to our model.
# This is what is also refered to as bias.
scaler = StandardScaler()
segmentation_std = scaler.fit_transform(df_segmentation)

# %% [markdown]
# ## ${\textbf{Hierarchical Clustering}}$

# %%
# Perform Hierarchical Clustering. The results are returned as a linkage matrix.
hier_clust = linkage(segmentation_std, method="ward")

# %%
# I plot the results from the Hierarchical Clustering using a Dendrogram.
# I truncate the dendrogram for better readability. The level p shows only the last p merged clusters
# I also omit showing the labels for each point.
plt.figure(figsize=(10, 6))
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hier_clust,
           truncate_mode="level",
           p=5,
           show_leaf_counts=False,
           no_labels=True)
plt.show()

# %% [markdown]
# ## ${\textbf{K-means Clustering}}$

# %%
# Perform K-means clustering. I consider 1 to 10 clusters, so our for loop runs 10 iterations.
# In addition I run the algortihm at many different starting points - k means plus plus.
# And I set a random state for reproducibility.
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init="k-means++", random_state=42, n_init=10)
    kmeans.fit(segmentation_std)
    wcss.append(kmeans.inertia_)

# %%
# Plot the Within Cluster Sum of Squares for the different number of clusters.
# From this plot I choose the number of clusters.
# I look for a kink in the graphic, after which the descent of wcss isn't as pronounced.
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), wcss, marker="o", linestyle="--")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.title("K-means Clustering")
plt.show()

# %%
# I run K-means with a fixed number of clusters. In our case 4.
kmeans = KMeans(n_clusters=4, init="k-means++", random_state=42, n_init=10)

# %%
# I divide our data into the four clusters.
kmeans.fit(segmentation_std)
# Out:
# KMeans(n_clusters=4, n_init=10, random_state=42)

# %% [markdown]
# ### ${\textbf{Results}}$

# %%
# I create a new data frame with the original features and add a new column with the assigned clusters for each point.
df_segm_kmeans = df_segmentation.copy()
df_segm_kmeans["Segment K-means"] = kmeans.labels_

# %%
# Calculate mean values for the clusters
df_segm_analysis = df_segm_kmeans.groupby(["Segment K-means"]).mean()
df_segm_analysis
# Out:
#                       Sex  Marital status        Age  Education  \
# Segment K-means
# 0                0.853901        0.997163  28.963121   1.068085
# 1                0.029825        0.173684  35.635088   0.733333
# 2                0.352814        0.019481  35.577922   0.746753
# 3                0.501901        0.692015  55.703422   2.129278
#
#                         Income  Occupation  Settlement size
# Segment K-means
# 0                105759.119149    0.634043         0.422695
# 1                141218.249123    1.271930         1.522807
# 2                 97859.852814    0.329004         0.043290
# 3                158338.422053    1.129278         1.110266

# %%
# Compute the size and proportions of the four clusters
df_segm_analysis["N Obs"] = (
    df_segm_kmeans[["Segment K-means", "Sex"]].groupby(["Segment K-means"]).count()
)
df_segm_analysis["Prop Obs"] = (
    df_segm_analysis["N Obs"] / df_segm_analysis["N Obs"].sum()
)

# %%
df_segm_analysis
# Out:
#                       Sex  Marital status        Age  Education  \
# Segment K-means
# 0                0.853901        0.997163  28.963121   1.068085
# 1                0.029825        0.173684  35.635088   0.733333
# 2                0.352814        0.019481  35.577922   0.746753
# 3                0.501901        0.692015  55.703422   2.129278
#
#                         Income  Occupation  Settlement size  N Obs  Prop Obs
# Segment K-means
# 0                105759.119149    0.634043         0.422695    705    0.3525
# 1                141218.249123    1.271930         1.522807    570    0.2850
# 2                 97859.852814    0.329004         0.043290    462    0.2310
# 3                158338.422053    1.129278         1.110266    263    0.1315

# %%
df_segm_analysis.rename(
    {0: "well-off", 1: "fewer-opportunities", 2: "standard", 3: "career focused"}
)
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means
# well-off             0.853901        0.997163  28.963121   1.068085
# fewer-opportunities  0.029825        0.173684  35.635088   0.733333
# standard             0.352814        0.019481  35.577922   0.746753
# career focused       0.501901        0.692015  55.703422   2.129278
#
#                             Income  Occupation  Settlement size  N Obs  \
# Segment K-means
# well-off             105759.119149    0.634043         0.422695    705
# fewer-opportunities  141218.249123    1.271930         1.522807    570
# standard              97859.852814    0.329004         0.043290    462
# career focused       158338.422053    1.129278         1.110266    263
#
#                      Prop Obs
# Segment K-means
# well-off               0.3525
# fewer-opportunities    0.2850
# standard               0.2310
# career focused         0.1315

# %%
# Add the segment labels to our table
df_segm_kmeans["Labels"] = df_segm_kmeans["Segment K-means"].map({
    0:
    "well-off",
    1:
    "fewer opportunities",
    2:
    "standard",
    3:
    "career focused"
})

# %%
# I plot the results from the K-means algorithm.
# Each point in our data set is plotted with the color of the clusters it has been assigned to.

plt.figure(figsize=(8, 8))
sns.scatterplot(
    data=df_segm_kmeans,
    x="Age",
    y="Income",
    hue=df_segm_kmeans["Labels"],
    palette="colorblind",
)
plt.title("Segmentation K-means")
plt.show()

# %% [markdown]
# ### ${\textbf{PCA}}$

# %%
# Employ PCA to find a subset of components, which explain the variance in the data.
pca = PCA()

# %%
# Fit PCA with our standardized data.
pca.fit(segmentation_std)
# Out:
# PCA()

# %%
# The attribute shows how much variance is explained by each of the seven individual components.
pca.explained_variance_ratio_
# Out:
# array([0.35696328, 0.26250923, 0.18821114, 0.0755775 , 0.05716512,
#        0.03954794, 0.02002579])

# %%
# Plot the cumulative variance explained by total number of components.
# On this graph I choose the subset of components I want to keep.
# Generally, I want to keep around 80 % of the explained variance.
plt.figure(figsize=(10, 6))
plt.plot(range(1, 8),
         pca.explained_variance_ratio_.cumsum(),
         marker="o",
         linestyle="--")
plt.title("Explained Variance by Components")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
# I choose three components. 3 or 4 seems the right choice according to the previous graph.
pca = PCA(n_components=3)

# %%
# Fit the model the our data with the selected number of components. In our case three.
pca.fit(segmentation_std)
# Out:
# PCA(n_components=3)

# %% [markdown]
# ### ${\textbf{PCA Results}}$

# %%
# Here I discucss the results from the PCA.
# The components attribute shows the loadings of each component on each of the seven original features.
# The loadings are the correlations between the components and the original features.
pca.components_
# Out:
# array([[-0.31469524, -0.19170439,  0.32609979,  0.15684089,  0.52452463,
#          0.49205868,  0.46478852],
#        [ 0.45800608,  0.51263492,  0.31220793,  0.63980683,  0.12468314,
#          0.01465779, -0.06963165],
#        [-0.29301261, -0.44197739,  0.60954372,  0.27560461, -0.16566231,
#         -0.39550539, -0.29568503]])

# %%
df_pca_comp = pd.DataFrame(
    data=pca.components_,
    columns=df_segmentation.columns.values,
    index=["Component 1", "Component 2", "Component 3"],
)


df_pca_comp
# Out:
#                   Sex  Marital status       Age  Education    Income  \
# Component 1 -0.314695       -0.191704  0.326100   0.156841  0.524525
# Component 2  0.458006        0.512635  0.312208   0.639807  0.124683
# Component 3 -0.293013       -0.441977  0.609544   0.275605 -0.165662
#
#              Occupation  Settlement size
# Component 1    0.492059         0.464789
# Component 2    0.014658        -0.069632
# Component 3   -0.395505        -0.295685

# %%
# Heat Map for Principal Components against original features. Again I use the crest color scheme and set borders to -1 and 1.
plt.figure(figsize=(10, 6))
sns.heatmap(df_pca_comp, vmin=-1, vmax=1, annot=True, cmap="crest")
plt.yticks([0, 1, 2], ["Component 1", "Component 2", "Component 3"],
           rotation=0,
           fontsize=10)
plt.xticks(rotation=45, fontsize=10)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]),
#  [Text(0.5, 0, 'Sex'),
#   Text(1.5, 0, 'Marital status'),
#   Text(2.5, 0, 'Age'),
#   Text(3.5, 0, 'Education'),
#   Text(4.5, 0, 'Income'),
#   Text(5.5, 0, 'Occupation'),
#   Text(6.5, 0, 'Settlement size')])

# %%
pca.transform(segmentation_std)
# Out:
# array([[ 2.51474593,  0.83412239,  2.1748059 ],
#        [ 0.34493528,  0.59814564, -2.21160279],
#        [-0.65106267, -0.68009318,  2.2804186 ],
#        ...,
#        [-1.45229829, -2.23593665,  0.89657125],
#        [-2.24145254,  0.62710847, -0.53045631],
#        [-1.86688505, -2.45467234,  0.66262172]])

# %%
scores_pca = pca.transform(segmentation_std)

# %% [markdown]
# ### ${\textbf{K-means clustering with PCA}}$

# %%
# I fit K means using the transformed data from the PCA.
wcss = []
for i in range(1, 11):
    kmeans_pca = KMeans(n_clusters=i, init="k-means++", random_state=42, n_init=10)

    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)

# %%
# Plot the Within Cluster Sum of Squares for the K-means PCA model. Here I make a decission about the number of clusters.
# Again it looks like four is the best option.
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), wcss, marker="o", linestyle="--")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.title("K-means with PCA Clustering")
plt.show()

# %%
# I have chosen four clusters, so I run K-means with number of clusters equals four.
# Same initializer and random state as before.
kmeans_pca = KMeans(n_clusters=4, init="k-means++", random_state=42, n_init=10)

# %%
# I fit our data with the k-means pca model
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(n_clusters=4, n_init=10, random_state=42)

# %% [markdown]
# ### ${\textbf{K-means clustering with PCA Results}}$

# %%
# I create a new data frame with the original features and add the PCA scores and assigned clusters.
df_segm_pca_kmeans = pd.concat(
    [df_segmentation.reset_index(drop=True), pd.DataFrame(scores_pca)], axis=1
)
df_segm_pca_kmeans.columns.values[-3:] = ["Component 1", "Component 2", "Component 3"]
# The last column I add contains the pca k-means clustering labels.
df_segm_pca_kmeans["Segment K-means PCA"] = kmeans_pca.labels_

# %%
df_segm_pca_kmeans
# Out:
#       Sex  Marital status  Age  Education  Income  Occupation  \
# 0       0               0   67          2  124670           1
# 1       1               1   22          1  150773           1
# 2       0               0   49          1   89210           0
# 3       0               0   45          1  171565           1
# 4       0               0   53          1  149031           1
# ...   ...             ...  ...        ...     ...         ...
# 1995    1               0   47          1  123525           0
# 1996    1               1   27          1  117744           1
# 1997    0               0   31          0   86400           0
# 1998    1               1   24          1   97968           0
# 1999    0               0   25          0   68416           0
#
#       Settlement size  Component 1  Component 2  Component 3  \
# 0                   2     2.514746     0.834122     2.174806
# 1                   2     0.344935     0.598146    -2.211603
# ...

# %%
# I calculate the means by segments.
df_segm_pca_kmeans_freq = df_segm_pca_kmeans.groupby(["Segment K-means PCA"]).mean()
df_segm_pca_kmeans_freq
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# 0                    0.900289        0.965318  28.878613   1.060694
# 1                    0.027444        0.168096  35.737564   0.734134
# 2                    0.505660        0.690566  55.679245   2.128302
# 3                    0.306522        0.095652  35.313043   0.760870
#
#                             Income  Occupation  Settlement size  Component 1  \
# Segment K-means PCA
# 0                    107551.500000    0.677746         0.440751    -1.107019
# 1                    141525.826758    1.267581         1.480274     1.372663
# 2                    158019.101887    1.120755         1.101887     1.687328
# 3                     93692.567391    0.252174         0.039130    -1.046406
#
#                      Component 2  Component 3
# Segment K-means PCA
# 0                       0.703776    -0.781410
# 1                      -1.046172    -0.248046
# ...

# %%
# Calculate the size of each cluster and its proportion to the entire data set.
df_segm_pca_kmeans_freq["N Obs"] = (df_segm_pca_kmeans[[
    "Segment K-means PCA", "Sex"
]].groupby(["Segment K-means PCA"]).count())
df_segm_pca_kmeans_freq["Prop Obs"] = (df_segm_pca_kmeans_freq["N Obs"] /
                                       df_segm_pca_kmeans_freq["N Obs"].sum())
df_segm_pca_kmeans_freq = df_segm_pca_kmeans_freq.rename({
    0: "standard",
    1: "career focused",
    2: "fewer opportunities",
    3: "well-off"
})
df_segm_pca_kmeans_freq
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# standard             0.900289        0.965318  28.878613   1.060694
# career focused       0.027444        0.168096  35.737564   0.734134
# fewer opportunities  0.505660        0.690566  55.679245   2.128302
# well-off             0.306522        0.095652  35.313043   0.760870
#
#                             Income  Occupation  Settlement size  Component 1  \
# Segment K-means PCA
# standard             107551.500000    0.677746         0.440751    -1.107019
# career focused       141525.826758    1.267581         1.480274     1.372663
# fewer opportunities  158019.101887    1.120755         1.101887     1.687328
# well-off              93692.567391    0.252174         0.039130    -1.046406
#
#                      Component 2  Component 3  N Obs  Prop Obs
# Segment K-means PCA
# standard                0.703776    -0.781410    692    0.3460
# ...

# %%
df_segm_pca_kmeans["Legend"] = df_segm_pca_kmeans["Segment K-means PCA"].map(
    {0: "standard", 1: "career focused", 2: "fewer opportunities", 3: "well-off"}
)

# %%
# Plot data by PCA components. The Y axis is the first component, X axis is the second.
plt.figure(figsize=(8, 8))
sns.scatterplot(
    data=df_segm_pca_kmeans,
    x="Component 2",
    y="Component 1",
    hue="Legend",
    palette="colorblind",
)
plt.title("Clusters by PCA Components")
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(
    data=df_segm_pca_kmeans,
    x="Component 3",
    y="Component 1",
    hue="Legend",
    palette="colorblind",
)
plt.title("Clusters by PCA Components")
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(
    data=df_segm_pca_kmeans,
    x="Component 3",
    y="Component 2",
    hue="Legend",
    palette="colorblind",
)
plt.title("Clusters by PCA Components")
plt.show()

# %% [markdown]
# ### ${\textbf{Data Export}}$

# %%
# I save the objects I'll need in the Purchase Analytics part of the course. I export them as pickle objects.
# I need the scaler, pca and kmeans_pca objects to preprocess and segment the purchase data set.
pickle.dump(scaler, open("scaler.pickle", "wb"))

# %%
pickle.dump(pca, open("pca.pickle", "wb"))

# %%
pickle.dump(kmeans_pca, open("kmeans_pca.pickle", "wb"))

# %%
kmeans_pca.labels_
# Out:
# array([2, 0, 3, ..., 3, 0, 3])
